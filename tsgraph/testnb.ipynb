# %%
import pickle

from tests.utils import timeseries
from tsgraph.nodes.core import df_node
from tsgraph.nodes.utils import diff
from tsgraph.render import node_graph

n = diff(df_node(timeseries([1,2,3,4,5,6,7])), 3)
node_graph(n)

# %%
s = pickle.dumps(n)
n2 = pickle.loads(s)
node_graph(n2)
# Out:
# ---------------------------------------------------------------------------
# PicklingError                             Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 s = pickle.dumps(n)
#       2 n2 = pickle.loads(s)
#       3 node_graph(n2)
#
# PicklingError: Can't pickle <function lag at 0x7f1eceb48400>: it's not the same object as tsgraph.nodes.utils.lag
