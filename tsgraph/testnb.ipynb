# %%
from tests.utils import timeseries
from tsgraph.node import df_node
from tsgraph.nodes.maths import diff
from tsgraph.render import node_graph

n = diff(df_node(timeseries([1,2,3,4,5,6,7])), 3)
node_graph(n)

# %%
n.calc()
print('xxx')
n.calc()
# Out:
# reset df_node(139942114674880)
# reset df_node(139942114674880)
# reset lag(139942114342672)
# reset mul(139942114674400)
# reset df_node(139942114674880)
# reset align_ffill(139942114674928)
# reset add(139942114674304)
# xxx
# reset df_node(139942114674880)
# reset df_node(139942114674880)
# reset lag(139942114342672)
# reset mul(139942114674400)
# reset df_node(139942114674880)
# reset align_ffill(139942114674928)
# reset add(139942114674304)
#               0
# 2000-01-04  3.0
# 2000-01-05  3.0
# 2000-01-06  3.0
# 2000-01-07  3.0
